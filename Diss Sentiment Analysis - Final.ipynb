# %%
import pandas as pd
import numpy as np
import csv 
import dateutil.parser
import re

#text processing and cleaning
from textblob import TextBlob
import nltk
nltk.download('stopwords')
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))

#adapted from The AI & DS Channel (2022)

nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Max\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Max\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
df = pd.read_csv('cryptocurrencyL.csv') #Reads CSV with tweets we want to add sentiment to

# %%
df.head() #Checks CSV
# Out:
#             author id                 created_at geo                   id  \
# 0           380085192  2021-01-07 23:59:53+00:00      1347332160508846080
# 1  955234754462445568  2021-01-07 23:59:53+00:00      1347332158931800065
# 2          3256899989  2021-01-07 23:59:49+00:00      1347332140556558341
# 3          3256899989  2021-01-07 23:59:44+00:00      1347332118955831297
# 4          1686414942  2021-01-07 23:59:37+00:00      1347332091797667841
#
#   lang  like_count  quote_count  reply_count  retweet_count  \
# 0   en           0            0            0              2
# 1   en           2            0            0              1
# 2   en           0            0            0              0
# 3   en           0            0            0              0
# 4   en           0            0            1              0
#
#                source                                              tweet
# 0  Twitter for iPhone  RT @chadandjt: Discussing #bitcoin and #crypto...
# 1    Crypto Watch Bot  Best #cryptocurrency risk-adjusted returns in ...
# 2     Twitter Web App  @kucoincom Bee Network is the fastest growing ...
# 3     Twitter Web App  @GoTurkey Bee Network is the fastest growing c...
# 4     Twitter Web App  @GhisBernard  Speaking of Bitcoin, you should ...

# %%
df.columns #Checks columns
# Out:
# Index(['author id', 'created_at', 'geo', 'id', 'lang', 'like_count',
#        'quote_count', 'reply_count', 'retweet_count', 'source', 'tweet'],
#       dtype='object')

# %%
text_df = df.drop(['author id', 'geo', 'id','lang', 'like_count', 'quote_count', 'reply_count',
'retweet_count','source'], axis=1) #Drops specififed headers from tweet dataset
text_df.head() #Check dropped headers
# Out:
#                   created_at  \
# 0  2021-01-07 23:59:53+00:00
# 1  2021-01-07 23:59:53+00:00
# 2  2021-01-07 23:59:49+00:00
# 3  2021-01-07 23:59:44+00:00
# 4  2021-01-07 23:59:37+00:00
#
#                                                tweet
# 0  RT @chadandjt: Discussing #bitcoin and #crypto...
# 1  Best #cryptocurrency risk-adjusted returns in ...
# 2  @kucoincom Bee Network is the fastest growing ...
# 3  @GoTurkey Bee Network is the fastest growing c...
# 4  @GhisBernard  Speaking of Bitcoin, you should ...

# %%
text_df.head(None)
# Out:
#                       created_at  \
# 0      2021-01-07 23:59:53+00:00
# 1      2021-01-07 23:59:53+00:00
# 2      2021-01-07 23:59:49+00:00
# 3      2021-01-07 23:59:44+00:00
# 4      2021-01-07 23:59:37+00:00
# ...                          ...
# 41252  2022-01-13 23:48:19+00:00
# 41253  2022-01-13 23:48:19+00:00
# 41254  2022-01-13 23:48:19+00:00
# 41255  2022-01-13 23:48:18+00:00
# 41256  2022-01-13 23:48:18+00:00
#
#                                                    tweet
# 0      RT @chadandjt: Discussing #bitcoin and #crypto...
# 1      Best #cryptocurrency risk-adjusted returns in ...
# 2      @kucoincom Bee Network is the fastest growing ...
# 3      @GoTurkey Bee Network is the fastest growing c...
# 4      @GhisBernard  Speaking of Bitcoin, you should ...
# ...                                                  ...
# 41252  RT @senseishibtoken: The word of $SENSEI is tr...
# 41253  RT @KittyLin2222: Harmony One Robot! 😍😍🥰\nhttp...
# 41254  RT @elis_tech: In order to thank community mem...
# 41255  RT @senseishibtoken: The word of $SENSEI is tr...
# 41256  RT @senseishibtoken: The word of $SENSEI is tr...
#
# [41257 rows x 2 columns]

# %%
text_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41257 entries, 0 to 41256
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   created_at  41257 non-null  object
#  1   tweet       41257 non-null  object
# dtypes: object(2)
# memory usage: 644.8+ KB

# %%
def proc(tweet): #Outlines characters to clean in collected tweet text
    tweet = re.sub(r"https\S+|www\S+https\S+", '',tweet, flags=re.MULTILINE)
    tweet = re.sub(r'\@w+|\#','',tweet)
    tweet = re.sub(r'[^\w\s]','',tweet)
    text_tokens = word_tokenize(tweet)
    filtered_text = [w for w in text_tokens if not w in stop_words]
    return " ".join(filtered_text)

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Max\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
text_df.tweet = text_df['tweet'].apply(proc) #Applies cleaning function to the dataframe

# %%
text_df = text_df.drop_duplicates('tweet') #Removes duplicate tweets

# %%
stemmer = PorterStemmer() #stemming function
def stemming(data):
    text = [stemmer.stem(word) for word in data]
    return data

# %%
text_df['tweet'] = text_df['tweet'].apply(lambda x: stemming(x)) #applies stemming function to dataframe

# %%
text_df.head() #Checks application of stemming function
# Out:
#                   created_at  \
# 0  2021-01-07 23:59:53+00:00
# 1  2021-01-07 23:59:53+00:00
# 2  2021-01-07 23:59:49+00:00
# 3  2021-01-07 23:59:44+00:00
# 4  2021-01-07 23:59:37+00:00
#
#                                                tweet
# 0     RT chadandjt Discussing bitcoin cryptocurrency
# 1  Best cryptocurrency riskadjusted returns past ...
# 2  kucoincom Bee Network fastest growing cryptocu...
# 3  GoTurkey Bee Network fastest growing cryptocur...
# 4  GhisBernard Speaking Bitcoin join MEGA Pump Si...

# %%
def polarity(tweet): #Polarity function
    return TextBlob(tweet).sentiment.polarity

# %%
text_df['polarity'] = text_df['tweet'].apply(polarity) #Applies polarity function to the text dataframe

# %%
text_df.head(20) #Check polarity application
# Out:
#                    created_at  \
# 0   2021-01-07 23:59:53+00:00
# 1   2021-01-07 23:59:53+00:00
# 2   2021-01-07 23:59:49+00:00
# 3   2021-01-07 23:59:44+00:00
# 4   2021-01-07 23:59:37+00:00
# 5   2021-01-07 23:59:37+00:00
# 6   2021-01-07 23:59:36+00:00
# 8   2021-01-07 23:59:27+00:00
# 9   2021-01-07 23:59:23+00:00
# 10  2021-01-07 23:59:22+00:00
# 11  2021-01-07 23:59:21+00:00
# 12  2021-01-07 23:59:18+00:00
# 13  2021-01-07 23:59:13+00:00
# 14  2021-01-07 23:59:07+00:00
# 15  2021-01-07 23:58:48+00:00
# 16  2021-01-07 23:58:48+00:00
# 19  2021-01-07 23:58:19+00:00
# 20  2021-01-07 23:58:17+00:00
# 22  2021-01-07 23:58:00+00:00
# 23  2021-01-07 23:57:57+00:00
#
#                                                 tweet  polarity
# 0      RT chadandjt Discussing bitcoin cryptocurrency  0.000000
# 1   Best cryptocurrency riskadjusted returns past ...  0.375000
# 2   kucoincom Bee Network fastest growing cryptocu...  0.000000
# 3   GoTurkey Bee Network fastest growing cryptocur...  0.000000
# 4   GhisBernard Speaking Bitcoin join MEGA Pump Si...  0.500000
# 5   jsblokland Bee Network fastest growing cryptoc...  0.000000
# 6   RT gemsays Why whole banking system scam Filme...  0.233333
# 8   TheCryptoCandy HGerbal Bee Network fastest gro...  0.000000
# 9   YSEC getting closer release Cant wait farm div...  0.000000
# 10  The next 14 months going amazing Bitcoin Ether...  0.300000
# 11  get_pei HGerbal Bee Network fastest growing cr...  0.000000
# 12  Get crypto joining EOC airdrop latokens exchan...  0.050000
# 13  MicrosoftCEE Bee Network fastest growing crypt...  0.000000
# 14  TheCryptoDog Bee Network fastest growing crypt...  0.000000
# 15  RT business Grayscale worlds largest manager d...  0.000000
# 16  RT latokens Get share free tokens worth 19000 ...  0.308333
# 19                 Bitcoin rallies yet another record  0.000000
# 20  RT CNBCFastMoney Bitcoin million APompliano br...  0.000000
# 22  RT newmoneyreview If GoldmanSachs likes bitcoi... -0.500000
# 23  really wish understood stocks cryptocurrency b...  0.350000

# %%
def sentiment(label): #Sentiment function
    if label<0:
        return "Negative"
    elif label ==0:
        return "Neutral"
    elif label>0:
        return "Positive"

# %%
text_df['sentiment'] = text_df['polarity'].apply(sentiment) #Applies sentiment function to data frame

# %%
text_df.head() #Check sentiment application
# Out:
#                   created_at  \
# 0  2021-01-07 23:59:53+00:00
# 1  2021-01-07 23:59:53+00:00
# 2  2021-01-07 23:59:49+00:00
# 3  2021-01-07 23:59:44+00:00
# 4  2021-01-07 23:59:37+00:00
#
#                                                tweet  polarity sentiment
# 0     RT chadandjt Discussing bitcoin cryptocurrency     0.000   Neutral
# 1  Best cryptocurrency riskadjusted returns past ...     0.375  Positive
# 2  kucoincom Bee Network fastest growing cryptocu...     0.000   Neutral
# 3  GoTurkey Bee Network fastest growing cryptocur...     0.000   Neutral
# 4  GhisBernard Speaking Bitcoin join MEGA Pump Si...     0.500  Positive

# %%
text_df.to_csv("cryptoL1.csv") #Creates CSV with cleaned tweet text, sentiment labbels and removed personal information
